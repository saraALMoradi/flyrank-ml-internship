# %% [markdown]
# <a href="https://colab.research.google.com/github/saraALMoradi/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saraALMoradi/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Lane: Refresh / Content Opportunity Scoring
#
# I chose this lane because it focuses on helping content teams decide which pages should be reviewed first. Instead of checking every page manually, the data can be used to prioritize pages that are more likely to need updates. This can save time and support better decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Research Question: Which content pages should be prioritized for review and updating?
#
# Decision: Decide which pages should be reviewed first.
#
# Action: The content team reviews and updates the highest-priority pages.
#
# Cost of a wrong recommendation: If a healthy page is recommended, the team wastes time. If a declining page is missed, its performance may continue to decrease and valuable traffic could be lost.
#
# Machine learning can help identify patterns in the data and support better prioritization than reviewing pages manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import subprocess
import sys

REPO_URL = "https://github.com/saraALMoradi/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# The starter dataset contains 30,000 pages, providing enough data to explore content performance patterns. Among these pages, 16,262 are labeled as down, suggesting that many pages may require review or updates. The average CTR is 0.5107, showing that user engagement varies across the dataset. These observations support the Refresh / Content Opportunity Scoring lane because they highlight the need to prioritize pages for review instead of checking every page manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print(df["trend_direction"].value_counts())
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Number of pages: 30000
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# Average CTR: 0.5107

# %% [markdown]
# This project provides decision support based on observed patterns in the data. It can help identify pages that may need to be reviewed and prioritized, but it cannot prove cause-and-effect relationships or predict Google's ranking algorithm. The results should be used to support human decision-making, not replace it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
